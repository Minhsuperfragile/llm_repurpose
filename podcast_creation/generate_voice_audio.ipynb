# %%
from transformers import VitsModel, AutoTokenizer
import torch

model = VitsModel.from_pretrained("facebook/mms-tts-vie")
tokenizer = AutoTokenizer.from_pretrained("facebook/mms-tts-vie")

text = "Xin chào việt nam"
inputs = tokenizer(text, return_tensors="pt")

with torch.no_grad():
    output = model(**inputs).waveform
# Out:
# config.json:   0%|          | 0.00/1.64k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/145M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/289 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]

# %%
import scipy

scipy.io.wavfile.write("techno.wav", rate=model.config.sampling_rate, data=output)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 import scipy
# ----> 3 scipy.io.wavfile.write("techno.wav", rate=model.config.sampling_rate, data=output)
#
# File ~/anaconda3/envs/llmft/lib/python3.12/site-packages/scipy/io/wavfile.py:798, in write(filename, rate, data)
#     795 fs = rate
#     797 try:
# --> 798     dkind = data.dtype.kind
#     799     allowed_dtypes = ['float32', 'float64',
#     800                       'uint8', 'int16', 'int32', 'int64']
#     801     if data.dtype.name not in allowed_dtypes:
#
# AttributeError: 'torch.dtype' object has no attribute 'kind'

# %%
from IPython.display import Audio

Audio(output, rate=model.config.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip show accelerate
# Out:
# Name: accelerate
# Version: 1.1.1
# Summary: Accelerate
# Home-page: https://github.com/huggingface/accelerate
# Author: The HuggingFace team
# Author-email: zach.mueller@huggingface.co
# License: Apache
# Location: /home/tminh/anaconda3/envs/llmft/lib/python3.12/site-packages
# Requires: huggingface-hub, numpy, packaging, psutil, pyyaml, safetensors, torch
# Required-by: nnsight, peft, pyreft, pyvene, trl, unsloth_zoo
